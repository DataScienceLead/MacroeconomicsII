# %% [markdown]
# # Load and analyse GDP data
# * Created: 26-09.2018
# * By: Joakim Blix Prestmo

# %% [markdown]
# ## Import libraries

# %%
library(tidyverse) 
library(readxl)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %% [markdown]
# ## Load data

# %%
#webstring = 'http://www.ssb.no/statbank/sq/10010628/'
df = read_excel('../data/gdpFiguresStatsNorway.xlsx')

# %%
head(df)
#¤tail(df)
# Out:
#   X__1   Konsum i husholdninger og ideelle organisasjoner
# 1 1978K1 122919
# 2 1978K2 123703
# 3 1978K3 125303
# 4 1978K4 124430
# 5 1979K1 126817
# 6 1979K2 129678
#   Konsum i offentlig forvaltning Bruttoinvestering i fast realkapital
# 1 68961                          85491
# 2 67663                          83135
# 3 69510                          82682
# 4 70443                          87285
# 5 70977                          82501
# 6 72518                          88942
#   Lagerendring og statistiske avvik Eksport i alt Import i alt
# 1 23188                             73295         69888
# 2  3245                             97233         71259
# 3 20378                             80527         66907
# 4 15558                             84079         69818
# 5 16138                             82192         67213
# 6 16346                             83057         71617
#   Bruttonasjonalprodukt, markedsverdi
# 1 293066
# 2 297817
# 3 301391
# 4 301788
# 5 300470
# ...

# %% [markdown]
# # Transform dataset
# * Add index
# * Change variabel names (colum header)

# %%
colnames(df) = c('time', 'PrivateConsumption', 'PublicConsumption', 'Investments', 'Error', 'Exports', 'Imports', 'GDP', 'GDPMainland')

# %%
df_ts = ts(df, frequency=4, start=c(1978,1))
# Out:
# Warning message in data.matrix(data):
# “NAs introduced by coercion”

# %%
df_ts
# Out:
#       X__1 Konsum i husholdninger og ideelle organisasjoner
#  [1,] NA   122919
#  [2,] NA   123703
#  [3,] NA   125303
#  [4,] NA   124430
#  [5,] NA   126817
#  [6,] NA   129678
#  [7,] NA   129761
#  [8,] NA   131001
#  [9,] NA   130856
# [10,] NA   130062
# [11,] NA   131344
# [12,] NA   132654
# [13,] NA   131552
# [14,] NA   131673
# [15,] NA   130233
# [16,] NA   134586
# [17,] NA   133009
# [18,] NA   134516
# [19,] NA   133873
# [20,] NA   133279
# [21,] NA   135741
# [22,] NA   135710
# [23,] NA   137436
# [24,] NA   136928
# [25,] NA   137560
# [26,] NA   140037
# [27,] NA   141160
# [28,] NA   143912
# [29,] NA   150026
# [30,] NA   151664
# [31,] ⋮    ⋮
# [32,] NA   310028
# [33,] NA   312031
# [34,] NA   313182
# [35,] NA   316696
# [36,] NA   320374
# [37,] NA   323568
# [38,] NA   325768
# [39,] NA   326343
# [40,] NA   331424
# [41,] NA   332653
# [42,] NA   334943
# [43,] NA   335633
# [44,] NA   337558
# [45,] NA   340567
# [46,] NA   341134
# [47,] NA   343662
# ...

# %%
#gdp = df$GDP
#time = df$time
df_ts
# Out:
#       time PrivateConsumption PublicConsumption Investments Error Exports
#  [1,] NA   122919             68961              85491      23188  73295
#  [2,] NA   123703             67663              83135       3245  97233
#  [3,] NA   125303             69510              82682      20378  80527
#  [4,] NA   124430             70443              87285      15558  84079
#  [5,] NA   126817             70977              82501      16138  82192
#  [6,] NA   129678             72518              88942      16346  83057
#  [7,] NA   129761             73158              89162      19530  88230
#  [8,] NA   131001             73865              84699      18948  90190
#  [9,] NA   130856             74757              81207      30257  97971
# [10,] NA   130062             74904              85563      27723  91368
# [11,] NA   131344             75862              88340      25057  80884
# [12,] NA   132654             76692              85338      21161  89519
# ...

# %% [markdown]
# # Simple plots and visualization

# %%
plot(df$"Imports",type="line")
# Out:
# Warning message in plot.xy(xy, type, ...):
# “plot type 'line' will be truncated to first character”
# plot without title

# %%
#install.packages("timeSeries", repos='http://cran.us.r-project.org')
#install.packages("fTrading", repos='http://cran.us.r-project.org')
#install.packages("PerformanceAnalytics", repos='http://cran.us.r-project.org')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependencies ‘gss’, ‘stabledist’, ‘fBasics’
#
# Warning message in install.packages("fTrading", repos = "http://cran.us.r-project.org"):
# “installation of package ‘gss’ had non-zero exit status”Warning message in install.packages("fTrading", repos = "http://cran.us.r-project.org"):
# “installation of package ‘fBasics’ had non-zero exit status”Warning message in install.packages("fTrading", repos = "http://cran.us.r-project.org"):
# “installation of package ‘fTrading’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependency ‘quadprog’
#
# Warning message in install.packages("PerformanceAnalytics", repos = "http://cran.us.r-project.org"):
# “installation of package ‘quadprog’ had non-zero exit status”Warning message in install.packages("PerformanceAnalytics", repos = "http://cran.us.r-project.org"):
# ...

# %%
library(timeSeries) 
require(xts)
require(PerformanceAnalytics)
require(fTrading)
# Out:
# Loading required package: timeDate
#
# Attaching package: ‘timeSeries’
#
# The following object is masked from ‘package:zoo’:
#
#     time<-
#
# Loading required package: PerformanceAnalytics
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘PerformanceAnalytics’”Loading required package: fTrading
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘fTrading’”

# %%
Consumption <- (df_ts[, 2])
PublicConsumption <- df_ts[,3]
Investments <- df_ts[,4]
Exports <- df_ts[,6]
Imports <- df_ts[,7]
GDP <- df_ts[,8]
GDPMainland <- df_ts[,9]

# %%
par(mfrow=c(1, 1))
plot(GDP,plot.type='s')
# Out:
# plot without title

# %% [markdown]
# ## Make growth rates

# %%
GDP_growth <- (GPD - )
