# %%
import pandas as pd
#import matplotlib as plt
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
# Open data from Statistics Norway, www.ssb.no
# Quarterly national account: 
# https://www.ssb.no/en/statbank/list/knr

# dataset = "http://www.ssb.no/statbank/sq/10010628/"
dataset = "http://www.ssb.no/statbank/sq/10024308/"
df = pd.read_excel(dataset, skiprows=3, skipfooter=48)

# %%
# Simple time series plot
df['Konsum i husholdninger og ideelle organisasjoner'].plot()
plt.show()

# %%
df.head()
# Out:
#   Unnamed: 0      Menn
# 0        NaN  15-74 år
# 1    2018M10        62
# 2    2018M11        58
# 3    2018M12        56
# 4    2019M01        58

# %%
# Add title and legend
df['Konsum i husholdninger og ideelle organisasjoner'].plot()
plt.title("Figure 1.1: Consumption")
plt.legend()
plt.xlabel('Date', fontdict=None, labelpad=None)
plt.ylabel('MNOK')

# save figure and use in presentataion etc. 
folder ='C:\\Users\\i235jbp\\Documents\\GitHub\\MacroeconomicsII\\'
filename = folder + 'consumption1.png'
plt.savefig(filename)
plt.show()

# %%
# Create growth rates:
# df[log_C] = ...
df['Dc'] = np.log(df['Konsum i husholdninger og ideelle organisasjoner']).diff(4)

df['DC_Y'] = df['Konsum i husholdninger og ideelle organisasjoner'].diff(4)/(df['Bruttonasjonalprodukt Fastlands-Norge, markedsverdi'].shift(4))
# Remember that using difference of the logarithm is an approximation that works as long as the relavtive change is small
# Note small letters for logarithms

# Figure with title and legend
df['DC_Y'].plot()
plt.title("Figure 1.2: Yearly change in consumption")
plt.legend()
plt.xlabel('Date', fontdict=None, labelpad=None)
plt.ylabel('MNOK')

# save figure and use in presentataion etc. 
filename_2 = folder + 'consumption2.png'
plt.savefig(filename_2)
plt.show()

# %%
import  pptx
# *pptx.exc as expections
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c3e75e718020> in <module>()
# ----> 1 import  pptx
#       2 # *pptx.exc as expections
#
# ~\Anaconda3\lib\site-packages\pptx\__init__.py in <module>()
#       6
#       7
# ----> 8 import pptx.exc as exceptions
#       9 import sys
#      10
#
# AttributeError: module 'pptx' has no attribute 'exc'

# %%
#Powerpoint presentation
from pptx import Presentation
from pptx.util import Inches


import pptx
pptx.__file__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-11eb874e2b1e> in <module>()
#       1 #Powerpoint presentation
# ----> 2 from pptx import Presentation
#       3 from pptx.util import Inches
#       4
#       5
#
# ~\Anaconda3\lib\site-packages\pptx\__init__.py in <module>()
#       6
#       7
# ----> 8 import pptx.exc as exceptions
#       9 import sys
#      10
#
# AttributeError: module 'pptx' has no attribute 'exc'

# %%
#Slide 1
prs = Presentation()
title_slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]

title.text = "Powerpoint via Python"
subtitle.text = "Consumption"

# %%
#Side 2 - med bilde
blank_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(blank_slide_layout)
#####


txBox = slide.shapes.add_textbox(left = Inches(4), top=Inches(1), width=Inches(1), height=Inches(1))
tf = txBox.text_frame


tf.text = "Consumption"
#####
bilde = filename


pic = slide.shapes.add_picture(bilde, left=Inches(1), top=Inches(2),width=Inches(7.5))

# %%
#Slide 3 
blank_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(blank_slide_layout)
#####


txBox = slide.shapes.add_textbox(left = Inches(4), top=Inches(1), width=Inches(1), height=Inches(1))
tf = txBox.text_frame


tf.text = "Endring konsum"
#####
bilde_2 = filename_2


pic2 = slide.shapes.add_picture(bilde_2, left=Inches(1), top=Inches(2),width=Inches(7.5))

prs.save('ppt_joakim.pptx') #Bare lag en ny pptx-fil der du lagrer med samme navn i samme folder.
